# %%
df = spark.read.csv('dbfs:/FileStore/shared_uploads/divyanksharma@deloitte.com/data.csv',header = True)

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
 df.printSchema()
# Out:
# root
#  |-- Loan_Id: string (nullable = true)
#  |-- Disbursed_Amount: string (nullable = true)
#  |-- Asset_Cost: string (nullable = true)
#  |-- ltv: string (nullable = true)
#  |-- Branch_Id: string (nullable = true)
#  |-- City_Code: string (nullable = true)
#  |-- State_Code: string (nullable = true)
#  |-- Postal_Code: string (nullable = true)
#  |-- Date_of_Birth: string (nullable = true)
#  |-- Employment_Type: string (nullable = true)
#  |-- DisbursalDate: string (nullable = true)
#  |-- MobileNo_Avl_Flag: string (nullable = true)
#  |-- Aadhar_flag: string (nullable = true)
#  |-- PAN_flag: string (nullable = true)
#  |-- VoterID_flag: string (nullable = true)
#  |-- Driving_flag: string (nullable = true)
#  |-- Passport_flag: string (nullable = true)
#  |-- PERFORM_CNS.SCORE: string (nullable = true)
#  |-- DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS: string (nullable = true)
#  |-- CREDIT.HISTORY.LENGTH: string (nullable = true)
#  |-- NO.OF_INQUIRIES: string (nullable = true)
# ...

# %%
type(df)
# Out:
# Out[13]: pyspark.sql.dataframe.DataFrame

# %%
from pyspark.sql import HiveContext
from pyspark.sql.types import *
from pyspark.sql import Row

# %%
hc = HiveContext(sc)
df.write.format("orc").saveAsTable("Loan_Data")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# <command-4203747948591703> in <module>
#       1 hc = HiveContext(sc)
# ----> 2 df.write.format("orc").saveAsTable("Loan_Data")
#
# /databricks/spark/python/pyspark/sql/readwriter.py in saveAsTable(self, name, format, mode, partitionBy, **options)
#     804         if format is not None:
#     805             self.format(format)
# --> 806         self._jwrite.saveAsTable(name)
#     807
#     808     def json(self, path, mode=None, compression=None, dateFormat=None, timestampFormat=None,
#
# /databricks/spark/python/lib/py4j-0.10.9.1-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1302
#    1303         answer = self.gateway_client.send_command(command)
# -> 1304         return_value = get_return_value(
#    1305             answer, self.gateway_client, self.target_id, self.name)
#    1306
#
# ...

# %%
df2 = hc.sql("select * from Loan_Data")

# %%
df2.show(2)
# Out:
# +-------+----------------+----------+-----+---------+---------+----------+-----------+-------------+---------------+-------------+-----------------+-----------+--------+------------+------------+-------------+-----------------+-----------------------------------+---------------------+---------------+-----------+---------+------------+---------+-----------+------+---+
# |Loan_Id|Disbursed_Amount|Asset_Cost|  ltv|Branch_Id|City_Code|State_Code|Postal_Code|Date_of_Birth|Employment_Type|DisbursalDate|MobileNo_Avl_Flag|Aadhar_flag|PAN_flag|VoterID_flag|Driving_flag|Passport_flag|PERFORM_CNS.SCORE|DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS|CREDIT.HISTORY.LENGTH|NO.OF_INQUIRIES|Region_code|City_Name|Loan_Default|Region_ID| State_Name|Region|KYC|
# ...

# %%
df3=hc.sql("select Loan_Id from Loan_Data")
